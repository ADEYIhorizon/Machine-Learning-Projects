# %%
pip install BeautifulSoup4

# %%
import requests
from bs4 import BeautifulSoup

URL = "https://www.finelib.com/agriculture/-agricultural-finance"
page = requests.get(URL)

soup = BeautifulSoup(page.content, "html.parser")

# %%
job_elements = soup.find_all("div", class_="box-682")

# %%
job_elements
# Out:
# [<div class="box-682">
#  <div class="box-headings">
#  <div style="overflow: auto;">
#  <div style="float: left;"> Agricultural Finance</div>
#  <div class="custom-spacing-box">
#  </div>
#  </div>
#  </div>
#  <div class="category-list newlist" style="float:none; margin:10px; margin-top:0; border:1px solid #cacaca; background:#fff;">
#  <ul>
#  <li><a href="/agriculture/-agricultural-finance/agricultural-grants-and-loans">Agricultural Grants and Loans</a></li>
#  </ul>
#  </div>
#  </div>, <div class="box-682 bg-none">
#  <div class="box-headings box-new-hed">
#  <div class="right"></div>
#  <span class="hd-number">1</span><a href="/listing/Nigerian-Agricultural-Insurance-Corporation/9322/">﻿Nigerian Agricultural Insurance Corporation</a>
#  </div>
#  <div class="bx-inner">
#  <div class="left-img-listing"><img alt="" class="review-img-border-2 left company_logo_tn" src="/images/listings/tn/9322_company_logo.jpg"/></div>
#  <div class="listing-info-img">
# ...

# %%
for job_element in job_elements:
    # name = job_element.find("h2", class_="title")
    # company_element = job_element.find("a", class_="company")
    # logo_element = job_element.find("img", class_="company_logo_tn")
    logo_ele = job_element.find("div", class_="cmpny-lstng-1").get_text()

    # print(name.text)
    # print(company_element.text)
    # print(logo_element.text)
    print(logo_ele)
    print()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-15-09c42041b12e> in <module>()
#       3     # company_element = job_element.find("a", class_="company")
#       4     # logo_element = job_element.find("img", class_="company_logo_tn")
# ----> 5     logo_ele = job_element.find("div", class_="cmpny-lstng-1").get_text()
#       6
#       7     # print(name.text)
#
# AttributeError: 'NoneType' object has no attribute 'get_text'
