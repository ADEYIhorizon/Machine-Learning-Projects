# %% [markdown]
# ### Import Libraries

# %%
from __future__ import print_function

import keras
import tensorflow
from keras.datasets import mnist
from keras.models import Sequential
from keras.layers import Dense, Dropout
from tensorflow.keras.optimizers import RMSprop

# %% [markdown]
# ### Defining batch size, classes and epochs

# %%
batch_size = 128
num_classes = 10
epochs = 20

# %% [markdown]
# ### The data, split between train and test sets

# %%
(x_train, y_train), (x_test, y_test) = mnist.load_data()

x_train = x_train.reshape(60000, 784)
x_test = x_test.reshape(10000, 784)
x_train = x_train.astype('float32')
x_test = x_test.astype('float32')
x_train /= 255
x_test /= 255
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/mnist.npz
# 11493376/11490434 [==============================] - 0s 0us/step
# 11501568/11490434 [==============================] - 0s 0us/step

# %% [markdown]
# ### Print the shape of the data

# %%
print(x_train.shape[0], 'train samples')
print(x_test.shape[0], 'test samples')
# Out:
# 60000 train samples
# 10000 test samples

# %% [markdown]
# ### Convert class vectors to binary class matrices

# %%
y_train = tensorflow.keras.utils.to_categorical(y_train, num_classes)
y_test = tensorflow.keras.utils.to_categorical(y_test, num_classes)

# %% [markdown]
# ### Build the model

# %%
model = Sequential()
model.add(Dense(512, activation='relu', input_shape=(784,)))
model.add(Dropout(0.2))
model.add(Dense(512, activation='relu'))
model.add(Dropout(0.2))
model.add(Dense(num_classes, activation='softmax'))

model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense (Dense)               (None, 512)               401920
#
#  dropout (Dropout)           (None, 512)               0
#
#  dense_1 (Dense)             (None, 512)               262656
#
#  dropout_1 (Dropout)         (None, 512)               0
#
#  dense_2 (Dense)             (None, 10)                5130
#
# =================================================================
# Total params: 669,706
# Trainable params: 669,706
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# ### Compile the model

# %%
model.compile(loss='categorical_crossentropy',
              optimizer=RMSprop(),
              metrics=['accuracy'])

# %% [markdown]
# ### Fit the model

# %%
history = model.fit(x_train, y_train,
                    batch_size=batch_size,
                    epochs=epochs,
                    verbose=1,
                    validation_data=(x_test, y_test))
score = model.evaluate(x_test, y_test, verbose=0)
# Out:
# Epoch 1/20
# 469/469 [==============================] - 10s 19ms/step - loss: 0.2460 - accuracy: 0.9243 - val_loss: 0.1104 - val_accuracy: 0.9651
# Epoch 2/20
# 469/469 [==============================] - 9s 19ms/step - loss: 0.1030 - accuracy: 0.9690 - val_loss: 0.1094 - val_accuracy: 0.9668
# Epoch 3/20
# 469/469 [==============================] - 9s 18ms/step - loss: 0.0737 - accuracy: 0.9768 - val_loss: 0.0786 - val_accuracy: 0.9787
# Epoch 4/20
# 469/469 [==============================] - 8s 18ms/step - loss: 0.0581 - accuracy: 0.9818 - val_loss: 0.0752 - val_accuracy: 0.9791
# Epoch 5/20
# 469/469 [==============================] - 9s 18ms/step - loss: 0.0493 - accuracy: 0.9854 - val_loss: 0.0771 - val_accuracy: 0.9801
# Epoch 6/20
# 469/469 [==============================] - 9s 18ms/step - loss: 0.0435 - accuracy: 0.9873 - val_loss: 0.0771 - val_accuracy: 0.9815
# Epoch 7/20
# 469/469 [==============================] - 9s 18ms/step - loss: 0.0376 - accuracy: 0.9882 - val_loss: 0.0775 - val_accuracy: 0.9815
# Epoch 8/20
# 469/469 [==============================] - 9s 18ms/step - loss: 0.0338 - accuracy: 0.9897 - val_loss: 0.0806 - val_accuracy: 0.9832
# Epoch 9/20
# 469/469 [==============================] - 9s 18ms/step - loss: 0.0304 - accuracy: 0.9909 - val_loss: 0.0679 - val_accuracy: 0.9842
# Epoch 10/20
# 469/469 [==============================] - 9s 18ms/step - loss: 0.0284 - accuracy: 0.9920 - val_loss: 0.1073 - val_accuracy: 0.9776
# Epoch 11/20
# 469/469 [==============================] - 9s 18ms/step - loss: 0.0274 - accuracy: 0.9918 - val_loss: 0.0824 - val_accuracy: 0.9826
# Epoch 12/20
# 469/469 [==============================] - 9s 18ms/step - loss: 0.0244 - accuracy: 0.9931 - val_loss: 0.0931 - val_accuracy: 0.9838
# Epoch 13/20
# 469/469 [==============================] - 9s 18ms/step - loss: 0.0236 - accuracy: 0.9935 - val_loss: 0.1010 - val_accuracy: 0.9826
# Epoch 14/20
# 469/469 [==============================] - 9s 18ms/step - loss: 0.0215 - accuracy: 0.9940 - val_loss: 0.0913 - val_accuracy: 0.9822
# Epoch 15/20
# 469/469 [==============================] - 9s 18ms/step - loss: 0.0211 - accuracy: 0.9936 - val_loss: 0.1036 - val_accuracy: 0.9845
# Epoch 16/20
# 469/469 [==============================] - 9s 18ms/step - loss: 0.0198 - accuracy: 0.9943 - val_loss: 0.1219 - val_accuracy: 0.9832
# Epoch 17/20
# 469/469 [==============================] - 9s 18ms/step - loss: 0.0239 - accuracy: 0.9943 - val_loss: 0.1230 - val_accuracy: 0.9828
# Epoch 18/20
# 469/469 [==============================] - 9s 18ms/step - loss: 0.0207 - accuracy: 0.9951 - val_loss: 0.1166 - val_accuracy: 0.9821
# Epoch 19/20
# 469/469 [==============================] - 9s 19ms/step - loss: 0.0190 - accuracy: 0.9952 - val_loss: 0.1135 - val_accuracy: 0.9839
# Epoch 20/20
# 469/469 [==============================] - 9s 19ms/step - loss: 0.0161 - accuracy: 0.9954 - val_loss: 0.1371 - val_accuracy: 0.9829

# %%
print('Test loss:', score[0])
print('Test accuracy:', score[1])
# Out:
# Test loss: 0.186350203103865
# Test accuracy: 0.982699990272522

# %%
model.predict(x_test)
# Out:
# array([[4.4239324e-32, 2.2444533e-19, 3.6784780e-20, ..., 1.0000000e+00,
#         1.1101665e-25, 1.7799127e-16],
#        [0.0000000e+00, 3.1369636e-26, 1.0000000e+00, ..., 2.5145568e-37,
#         6.7361631e-36, 0.0000000e+00],
#        [5.7038497e-17, 1.0000000e+00, 1.7368808e-09, ..., 1.1063299e-10,
#         1.9319702e-12, 5.7102501e-17],
#        ...,
#        [4.8201881e-34, 7.8395584e-20, 1.6334000e-26, ..., 3.4071844e-17,
#         1.7775292e-18, 3.6987606e-13],
#        [2.6554000e-33, 6.3350777e-33, 0.0000000e+00, ..., 1.0567194e-28,
#         1.2212407e-15, 5.6998336e-29],
#        [0.0000000e+00, 0.0000000e+00, 7.8322987e-34, ..., 0.0000000e+00,
#         1.7825241e-36, 5.1256533e-38]], dtype=float32)
